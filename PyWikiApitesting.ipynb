# %%
from pywikiapi import wikipedia

# %%
site = wikipedia('en')

# %%
# Iterate over all query results as they are returned
# from the server, handling continuations automatically.
# (pages whose title begins with "New York-New Jersey")
for r in site.query(list='allpages', apprefix='New York'):
  for page in r.allpages:
    print(page.title)
# Out:
# New York
# New York's
# New York's 10th State Senate district
# New York's 10th congressional district
# New York's 10th congressional district special election, 1895
# New York's 10th congressional district special election, 1949
# New York's 11th Congressional district
# New York's 11th State Senate district
# New York's 11th congressional district
# New York's 11th congressional district special election, 1944
# New York's 11th congressional district special election, 2015
# New York's 12th Congressional District
# New York's 12th State Senate district
# New York's 12th congressional district
# New York's 12th congressional district special election
# New York's 12th congressional district special election, 1808
# New York's 12th congressional district special election, 1815
# New York's 13th State Senate district
# New York's 13th congressional district
# New York's 13th congressional district election, 2006
# New York's 13th congressional district special election, 1968
# ...
